# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("food_delivery_train.csv")
data
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
train = pd.read_csv("food_delivery_train.csv")

# %%
test = pd.read_csv("food_delivery_test.csv")

# %%
train
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
test
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x2318    COIMBRES13DEL01                 NaN                     NaN
# 1      0x3474     BANGRES15DEL01                   28                     4.6
# 2      0x9420      JAPRES09DEL03                   23                     4.5
# 3      0x72ee      JAPRES07DEL03                   21                     4.8
# 4      0xa759     CHENRES19DEL01                   31                     4.6
# ...        ...                ...                 ...                     ...
# 11394  0x6909      JAPRES01DEL01                   35                     4.6
# 11395  0x443b      JAPRES11DEL01                   33                     4.9
# 11396  0x1ea5      SURRES11DEL03                 NaN                     NaN
# 11397  0x22d4      VADRES03DEL02                   27                     4.7
# 11398  0xb7be     CHENRES07DEL02                   39                       5
#
# ...

# %%
full_data = pd.concat([train,test])

# %%
data = full_data.dropna(subset=['Time_taken(min)']).copy()

# %%
data
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
data.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
data.tail()
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
# ...

# %%
data.shape
# Out:
# (45593, 20)

# %%
data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
#  12  Road_traffic_density         45593 non-null  object
# ...

# %%
data.describe()
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         45593.000000          45593.000000                45593.000000
# mean             17.017729             70.231332                   17.465186
# std               8.185109             22.883647                    7.335122
# min             -30.905562            -88.366217                    0.010000
# 25%              12.933284             73.170000                   12.988453
# 50%              18.546947             75.898497                   18.633934
# 75%              22.728163             78.044095                   22.785049
# max              30.914057             88.433452                   31.054057
#
#        Delivery_location_longitude  Vehicle_condition
# count                 45593.000000       45593.000000
# mean                     70.845702           1.023359
# std                      21.118812           0.839065
# min                       0.010000           0.000000
# ...

# %%
data['Order_Date'] = pd.to_datetime(data['Order_Date'], dayfirst=True, errors='coerce')
data = data.dropna(subset=['Order_Date'])

# %%
data['Day'] = data['Order_Date'].dt.day_name()
data['Month'] = data['Order_Date'].dt.month

# %%
from math import radians, sin, cos, sqrt, atan2

def distance(lat1, lon1, lat2, lon2):
    R = 6371

    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)

    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2

    c = 2 * atan2(sqrt(a), sqrt(1-a))

    return R * c

data['distance_km'] = data.apply(
    lambda x: distance(
        x['Restaurant_latitude'],
        x['Restaurant_longitude'],
        x['Delivery_location_latitude'],
        x['Delivery_location_longitude']
    ),
    axis=1
)

# %%
data['Time_taken(min)'] = data['Time_taken(min)'].astype(str)
data['Time_taken(min)'] = data['Time_taken(min)'].str.extract('(\d+)')
data['Time_taken(min)'] = data['Time_taken(min)'].astype(float)

# %%
print(data['Time_taken(min)'].head())
print(data['Time_taken(min)'].dtype)
# Out:
# 0    24.0
# 1    33.0
# 2    26.0
# 3    21.0
# 4    30.0
# Name: Time_taken(min), dtype: float64
# float64

# %%
print(data['Time_taken(min)'].mean())
# Out:
# 26.29460662821047

# %%
print(data.groupby('City')['Time_taken(min)'].mean())
# Out:
# City
# Metropolitian     27.315226
# NaN               22.058333
# Semi-Urban        49.731707
# Urban             22.984017
# Name: Time_taken(min), dtype: float64

# %%
print(data.groupby('Road_traffic_density')['Time_taken(min)'].mean())
# Out:
# Road_traffic_density
# High       27.240000
# Jam        31.176624
# Low        21.266977
# Medium     26.699644
# NaN        26.542429
# Name: Time_taken(min), dtype: float64

# %%
print(data[['distance_km', 'Time_taken(min)']].corr())
# Out:
#                  distance_km  Time_taken(min)
# distance_km         1.000000        -0.002508
# Time_taken(min)    -0.002508         1.000000

# %%
import matplotlib.pyplot as plt

plt.hist(data['Time_taken(min)'])
plt.title("Delivery Time Distribution")
plt.show()

# %%
data.groupby('City')['Time_taken(min)'].mean().plot(kind='bar')
plt.title("City vs Delivery Time")
plt.show()

# %%
plt.scatter(data['distance_km'], data['Time_taken(min)'])
plt.xlabel("Distance")
plt.ylabel("Time")
plt.title("Distance vs Time")
plt.show()

# %%
data['is_weekend'] = data['Day'].isin(['Saturday', 'Sunday'])

# %%
print(data.groupby('is_weekend')['Time_taken(min)'].mean())
# Out:
# is_weekend
# False    26.311551
# True     26.249940
# Name: Time_taken(min), dtype: float64

# %%
data.groupby('is_weekend')['Time_taken(min)'].mean().plot(kind='bar')

plt.title("Weekend vs Weekday Delivery Time")
plt.xlabel("Weekend")
plt.ylabel("Average Time")
plt.show()

# %%
weather = data.groupby('Weatherconditions')['Time_taken(min)'].mean()

print(weather)
# Out:
# Weatherconditions
# conditions Cloudy        28.917330
# conditions Fog           28.916122
# conditions NaN           26.545455
# conditions Sandstorms    25.875517
# conditions Stormy        25.870815
# conditions Sunny         21.856947
# conditions Windy         26.118836
# Name: Time_taken(min), dtype: float64

# %%
weather.plot(kind='bar', color=['red', 'blue', 'green', 'orange', 'purple', 'pink'])

plt.title("Weather vs Delivery Time")
plt.xlabel("Weather")
plt.ylabel("Average Time")

plt.show()

# %%
traffic = data.groupby('Road_traffic_density')['Time_taken(min)'].mean()

print(traffic)
# Out:
# Road_traffic_density
# High       27.240000
# Jam        31.176624
# Low        21.266977
# Medium     26.699644
# NaN        26.542429
# Name: Time_taken(min), dtype: float64

# %%
traffic.plot(kind='bar', color=['red', 'blue', 'green', 'orange'])

plt.title("Traffic Density vs Delivery Time")
plt.xlabel("Traffic")
plt.ylabel("Average Time")

plt.show()

# %%
festival = data.groupby('Festival')['Time_taken(min)'].mean()

print(festival)
# Out:
# Festival
# NaN     11.166667
# No      25.984843
# Yes     45.517857
# Name: Time_taken(min), dtype: float64

# %%
festival.plot(kind='bar', color=['red', 'blue', 'green', 'orange', 'purple', 'pink'])

plt.title("Festival vs Delivery Time")
plt.xlabel("Festival")
plt.ylabel("Average Time")
plt.show()

# %%
plt.scatter(data['distance_km'], data['Time_taken(min)'])

plt.xlabel("Distance (km)")
plt.ylabel("Delivery Time (min)")
plt.title("Distance vs Delivery Time")

plt.show()

# %%
day_analysis = data.groupby('Day')['Time_taken(min)'].mean()

print(day_analysis)
# Out:
# Day
# Friday       26.817380
# Monday       26.254068
# Saturday     26.099841
# Sunday       26.401024
# Thursday     25.183207
# Tuesday      25.322196
# Wednesday    27.759481
# Name: Time_taken(min), dtype: float64

# %%
day_analysis.plot(kind='bar', color=['red', 'blue', 'green', 'orange', 'purple', 'pink'])

plt.title("Day vs Delivery Time")
plt.xlabel("Day")
plt.ylabel("Average Time")

plt.show()

# %%
weather = data.groupby('Weatherconditions')['Time_taken(min)'].mean()

ax = weather.plot(
    kind='bar',
    color=['skyblue', 'orange', 'green', 'red', 'purple'],
    edgecolor='black',
    figsize=(8,5),
    width=0.7
)

plt.title("Weather Impact on Delivery Time", fontsize=16)
plt.xlabel("Weather Conditions", fontsize=12)
plt.ylabel("Average Delivery Time", fontsize=12)

plt.xticks(rotation=45)

plt.grid(axis='y', linestyle='--', alpha=0.7)

# 🔥 Values on top of bars
for i in ax.patches:
    ax.text(
        i.get_x() + i.get_width()/2,
        i.get_height() + 0.5,
        round(i.get_height(), 1),
        ha='center'
    )

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter( data['distance_km'],data['Time_taken(min)'], color='purple',s=60, alpha=0.6,edgecolor='black')

plt.xlabel("Distance (km)", fontsize=12)
plt.ylabel("Delivery Time (min)", fontsize=12)

plt.title("Distance vs Delivery Time", fontsize=15)

plt.grid(alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    data['Time_taken(min)'],
    bins=20,
    color='skyblue',
    edgecolor='black'
)

plt.title("Delivery Time Distribution", fontsize=15)

plt.xlabel("Delivery Time (min)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

plt.grid(alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(14,10))

plt.subplot(2,2,1)

plt.hist(
    data['Time_taken(min)'],
    bins=20,
    color='skyblue',
    edgecolor='black'
)

plt.title("Delivery Time Distribution")



plt.subplot(2,2,2)

weather = data.groupby('Weatherconditions')['Time_taken(min)'].mean()

weather.plot(
    kind='bar',
    color=['orange', 'green', 'red', 'purple']
)

plt.title("Weather vs Delivery Time")



plt.subplot(2,2,3)

traffic = data.groupby('Road_traffic_density')['Time_taken(min)'].mean()

traffic.plot(
    kind='bar',
    color=['green', 'yellow', 'orange', 'red']
)

plt.title("Traffic vs Delivery Time")



plt.subplot(2,2,4)

plt.scatter(
    data['distance_km'],
    data['Time_taken(min)'],
    color='blue',
    alpha=0.5
)

plt.xlabel("Distance")
plt.ylabel("Time")

plt.title("Distance vs Delivery Time")


# Layout Fix
plt.tight_layout()

plt.show()

# %%
data.to_csv("cleaned_food_delivery.csv", index=False)
